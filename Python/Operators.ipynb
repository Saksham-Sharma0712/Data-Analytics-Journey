# %%
res = "Hi" + str(7)
res
# Out:
# 'Hi7'

# %%
a = 10 
b = 5
add = a + b
sub = a - b
mul = a * b
div = a / b
floorDiv = a // b
mod = a % b
floorDiv
# Out:
# 2

# %%
#comp oper
# == 
a = 10
b = 10
a == b
name = "Sam"
Name = "Sam"
name == Name
# Out:
# True

# %%
name != Name
# Out:
# False

# %%
#Greater than
a = 10
b = 20
b > a
# Out:
# True

# %%
a = 10
b = 10
a >= b
a <= b
# Out:
# True

# %%
X = True
Y = False
X and Y
# Out:
# False

# %%
X or Y
# Out:
# True

# %%
X = True
not X
# Out:
# False

# %%
#Simple calc
num1 = float(input("Enter num1"))
num2 = float(input("Enter num2"))
addn = num1 +num2
sub = num1 - num2
mul = num1 * num2
div = num1 / num2
floordiv =  num1 // num2
mod = num1 % num2
expo = num1 ** num2
print("addn is ", addn)
print("Subt is ",sub)
print("Multipl is",mul)
print("Divn is ",div)
print("Floor div is ",floordiv)
print("Modulus is ",mod)
print("Expon is ",expo)
# Out:
# Enter num1 2.5
# Enter num2 3
# addn is  5.5
# Subt is  -0.5
# Multipl is 7.5
# Divn is  0.8333333333333334
# Floor div is  0.0
# Modulus is  2.5
# Expon is  15.625

# %%
num = int(input("Enter num"))
if num > 0:
    print("positive")
elif num < 0:
    print("negative")
else:
    print(0)
# Out:
# Enter num 0
# 0

# %%
a = int(input("ENter val of a"))
b =int(input("Enter val of b"))
c = int(input("Enter val of c"))
if a > b and a > c:
    print("a is greater ")
elif b > a and b > c:
    print("b is greater")
elif c > a and c > b:
    print("c is greater")
else:
    print("Not a valid no")
# Out:
# ENter val of a -19
# Enter val of b -10
# Enter val of c -7
# c is greater

# %%
num = int(input("Enter number to find factorial"))
res = num
for i in range(1,num):
    res = res * (num - i)
print("factorial is ",res)
# Out:
# Enter number to find factorial 5
# factorial is  120

# %%
a = int(input("Enter val of a"))
b = int(input("Enter val of b"))
temp = a
b = a
a = b
print(a)
print(b)
# Out:
# Enter val of a 1
# Enter val of b 2
# 1
# 1

# %%
a = 10
b = 20
temp = b
b = a
a = temp
print(a)
print(b)
# Out:
# 20
# 10
